# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Deep_Learning/datasets/fuel_prices.csv')

# %%
df.head()
# Out:
#   Unnamed: 0  Unnamed: 1  Unnamed: 2  Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0        NaN         NaN         NaN         NaN       Date        Day
# 1        NaN         NaN         NaN         NaN        NaN        NaN
# 2        NaN         NaN         NaN         NaN  16 Jun 17     Friday
# 3        NaN         NaN         NaN         NaN  17 Jun 17   Saturday
# 4        NaN         NaN         NaN         NaN  18 Jun 17     Sunday
#
#      Unnamed: 6    Unnamed: 7    Unnamed: 8  Unnamed: 9  Unnamed: 10  \
# 0  Petrol Price  Diesel Price  Dollar Value  Oil Barrel  Barrel Cost
# 1           NaN           NaN           NaN         NaN          NaN
# 2         68.02         57.41        64.393       44.74   2880.94282
# 3         67.76         57.23       64.4388       44.58  2872.681704
# 4         67.42         57.03       64.3984       44.39  2858.644976
#
#   Unnamed: 11
# 0  Moving Avg
# 1         NaN
# 2           0
# 3           0
# 4           0

# %%
df.drop(['Unnamed: 0','Unnamed: 1','Unnamed: 2','Unnamed: 3'], axis= 1,inplace=True)

# %%
df.head()
# Out:
#   Unnamed: 4 Unnamed: 5    Unnamed: 6    Unnamed: 7    Unnamed: 8  Unnamed: 9  \
# 0       Date        Day  Petrol Price  Diesel Price  Dollar Value  Oil Barrel
# 1        NaN        NaN           NaN           NaN           NaN         NaN
# 2  16 Jun 17     Friday         68.02         57.41        64.393       44.74
# 3  17 Jun 17   Saturday         67.76         57.23       64.4388       44.58
# 4  18 Jun 17     Sunday         67.42         57.03       64.3984       44.39
#
#    Unnamed: 10 Unnamed: 11
# 0  Barrel Cost  Moving Avg
# 1          NaN         NaN
# 2   2880.94282           0
# 3  2872.681704           0
# 4  2858.644976           0

# %%
df.columns = df.iloc[0]

# %%
df.head()
# Out:
# 0       Date       Day  Petrol Price  Diesel Price  Dollar Value  Oil Barrel  \
# 0       Date       Day  Petrol Price  Diesel Price  Dollar Value  Oil Barrel
# 1        NaN       NaN           NaN           NaN           NaN         NaN
# 2  16 Jun 17    Friday         68.02         57.41        64.393       44.74
# 3  17 Jun 17  Saturday         67.76         57.23       64.4388       44.58
# 4  18 Jun 17    Sunday         67.42         57.03       64.3984       44.39
#
# 0  Barrel Cost  Moving Avg
# 0  Barrel Cost  Moving Avg
# 1          NaN         NaN
# 2   2880.94282           0
# 3  2872.681704           0
# 4  2858.644976           0

# %%
df.drop([0,1],axis=0,inplace=True)

# %%
df.head()
# Out:
# 0       Date       Day Petrol Price Diesel Price Dollar Value Oil Barrel  \
# 2  16 Jun 17    Friday        68.02        57.41       64.393      44.74
# 3  17 Jun 17  Saturday        67.76        57.23      64.4388      44.58
# 4  18 Jun 17    Sunday        67.42        57.03      64.3984      44.39
# 5  19 Jun 17    Monday        67.14        56.89      64.4906       44.2
# 6  20 Jun 17   Tuesday        67.04        56.85      64.6418      43.23
#
# 0  Barrel Cost    Moving Avg
# 2   2880.94282             0
# 3  2872.681704             0
# 4  2858.644976             0
# 5   2850.48452   2865.688505
# 6  2794.465014  2844.0690535

# %%
import plotly.graph_objs as go
import plotly

# %%
petrol  = go.Scatter( x=df['Date'], y=df['Petrol Price'],name = 'Petrol_Price_Per_date')
barrelCost = go.Scatter( x=df['Date'], y=df['Barrel Cost'],name='Barrel_cost')
data = [petrol, barrelCost]
layout = dict(title = 'Petrol price vs barrel price',
              xaxis= dict(title= 'Years',ticklen= 4,zeroline= False))
fig =dict(data = data, layout = layout)
plotly.offline.iplot(fig)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="16786174-8e06-476d-a9c3-7be955921d3d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("16786174-8e06-476d-a9c3-7be955921d3d")) {                    Plotly.newPlot(                        "16786174-8e06-476d-a9c3-7be955921d3d",                        [{"name":"Petrol_Price_Per_date","x":["16 Jun 17","17 Jun 17","18 Jun 17","19 Jun 17","20 Jun 17","21 Jun 17","22 Jun 17","23 Jun 17","24 Jun 17","25 Jun 17","26 Jun 17","27 Jun 17","28 Jun 17","29 Jun 17","30 Jun 17","1 Jul 17","2 Jul 17","3 Jul 17","4 Jul 17","5 Jul 17","6 Jul 17","7 Jul 17","8 Jul 17","9 Jul 17","10 Jul 17","11 Jul 17","12 Jul 17","13 Jul 17","14 Jul 17","15 Jul 17","16 Jul 17","17 Jul 17","18 Jul 17","19 Jul 17","20 Jul 17","21 Jul 17","22 Jul 17","23 Jul 17","24 Jul 17","25 Jul 17","26 Jul 17","27 Jul 17","28 Jul 17","29 Jul 17","30 Jul 17","31 Jul 17","1 Aug 17","2 Aug 17","3 Aug 17","4 Aug 17","5 Aug 17","6 Aug 17","7 Aug 17","8 Aug 17","9 Aug 17","10 Aug 17","11 Aug 17","12 Aug 17","13 Aug 17","14 Aug 17","15 Aug 17","16 Aug 17","17 Aug 17","18 Aug 17","19 Aug 17","20 Aug 17","21 Aug 17","22 Aug 17","23 Aug 17","24 Aug 17","25 Aug 17","26 Aug 17","27 Aug 17","28 Aug 17","29 Aug 17","30 Aug 17","31 Aug 17","1 Sep 17","2 Sep 17","3 Sep 17","4 Sep 17","5 Sep 17","6 Sep 17","7 Sep 17","8 Sep 17","9 Sep 17","10 Sep 17","11 Sep 17","12 Sep 17","13 Sep 17","14 Sep 17","15 Sep 17","16 Sep 17","17 Sep 17","18 Sep 17","19 Sep 17","20 Sep 17","21 Sep 17","22 Sep 17","23 Sep 17","24 Sep 17","25 Sep 17","26 Sep 17","27 Sep 17","28 Sep 17","29 Sep 17","30 Sep 17","1 Oct 17","2 Oct 17","3 Oct 17","4 Oct 17","5 Oct 17","6 Oct 17","7 Oct 17","8 Oct 17","9 Oct 17","10 Oct 17","11 Oct 17","12 Oct 17","13 Oct 17","14 Oct 17","15 Oct 17","16 Oct 17","17 Oct 17","18 Oct 17","19 Oct 17","20 Oct 17","21 Oct 17","22 Oct 17","23 Oct 17","24 Oct 17","25 Oct 17","26 Oct 17","27 Oct 17","28 Oct 17","29 Oct 17","30 Oct 17","31 Oct 17","1 Nov 17","2 Nov 17","3 Nov 17","4 Nov 17","5 Nov 17","6 Nov 17","7 Nov 17","8 Nov 17","9 Nov 17","10 Nov 17","11 Nov 17","12 Nov 17","13 Nov 17","14 Nov 17","15 Nov 17","16 Nov 17","17 Nov 17","18 Nov 17","19 Nov 17","20 Nov 17","21 Nov 17","22 Nov 17","23 Nov 17","24 Nov 17","25 Nov 17","26 Nov 17","27 Nov 17","28 Nov 17","29 Nov 17","30 Nov 17","1 Dec 17","2 Dec 17","3 Dec 17","4 Dec 17","5 Dec 17","6 Dec 17","7 Dec 17","8 Dec 17","9 Dec 17","10 Dec 17","11 Dec 17","12 Dec 17","13 Dec 17","14 Dec 17","15 Dec 17","16 Dec 17","17 Dec 17","18 Dec 17","19 Dec 17","20 Dec 17","21 Dec 17","22 Dec 17","23 Dec 17","24 Dec 17","25 Dec 17","26 Dec 17","27 Dec 17","28 Dec 17","29 Dec 17","30 Dec 17","31 Dec 17","1 Jan 18","2 Jan 18","3 Jan 18","4 Jan 18","5 Jan 18","6 Jan 18","7 Jan 18","8 Jan 18","9 Jan 18","10 Jan 18","11 Jan 18","12 Jan 18","13 Jan 18","14 Jan 18","15 Jan 18","16 Jan 18","17 Jan 18","18 Jan 18","19 Jan 18","20 Jan 18","21 Jan 18","22 Jan 18","23 Jan 18","24 Jan 18","25 Jan 18","26 Jan 18","27 Jan 18","28 Jan 18","29 Jan 18","30 Jan 18","31 Jan 18","1 Feb 18","2 Feb 18","3 Feb 18","4 Feb 18","5 Feb 18","6 Feb 18","7 Feb 18","8 Feb 18","9 Feb 18","10 Feb 18","11 Feb 18","12 Feb 18","13 Feb 18","14 Feb 18","15 Feb 18","16 Feb 18","17 Feb 18","18 Feb 18","19 Feb 18","20 Feb 18","21 Feb 18","22 Feb 18","23 Feb 18","24 Feb 18","25 Feb 18","26 Feb 18","27 Feb 18","28 Feb 18","1 Mar 18","2 Mar 18","3 Mar 18","4 Mar 18","5 Mar 18","6 Mar 18","7 Mar 18","8 Mar 18","9 Mar 18","10 Mar 18","11 Mar 18","12 Mar 18","13 Mar 18","14 Mar 18","15 Mar 18","16 Mar 18","17 Mar 18","18 Mar 18","19 Mar 18","20 Mar 18","21 Mar 18","22 Mar 18","23 Mar 18","24 Mar 18","25 Mar 18","26 Mar 18","27 Mar 18","28 Mar 18","29 Mar 18","30 Mar 18","31 Mar 18","1 Apr 18","2 Apr 18","3 Apr  ...

# %%
df.isnull().any()
# Out:
# 0
# Date            False
# Day             False
# Petrol Price    False
# Diesel Price    False
# Dollar Value    False
# Oil Barrel      False
# Barrel Cost     False
# Moving Avg      False
# dtype: bool

# %%
df1 = df.drop(['Date','Day','Moving Avg','Diesel Price','Barrel Cost'],axis=1,inplace=True)

# %%
df.head()
# Out:
# 0 Petrol Price Dollar Value Oil Barrel
# 2        68.02       64.393      44.74
# 3        67.76      64.4388      44.58
# 4        67.42      64.3984      44.39
# 5        67.14      64.4906       44.2
# 6        67.04      64.6418      43.23

# %%
x = df.drop(['Petrol Price'],axis =1)
y = df['Petrol Price']

# %%
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler()
x1=sc.fit_transform(x)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x1,y,test_size=0.25,random_state=None)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
model.predict(x_test)
# Out:
# array([69.29849694, 71.29942903, 71.0741329 , 73.28071993, 83.5833754 ,
#        72.34479205, 72.76530082, 72.78070457, 77.89971706, 72.72442925,
#        73.02097585, 74.48862935, 75.09236375, 69.05345076, 75.0940874 ,
#        68.23169807, 67.76870106, 73.06613544, 75.09902978, 67.96731415,
#        71.00311098, 79.47864922, 69.29481718, 68.82420642, 70.57480469,
#        71.17366996, 68.74274934, 74.85546615, 78.69187539, 78.90439845,
#        79.88579633, 80.047857  , 68.28288752, 77.96638538, 79.93945875,
#        78.21686101, 74.39260064, 71.10869905, 77.76165103, 75.48536111,
#        81.13305412, 69.22375366, 68.91157513, 74.54541833, 79.21865618,
#        75.04364746, 81.30398849, 77.70384651, 73.1869096 , 73.50043   ,
#        70.9723117 , 80.16168674, 68.77870813, 72.48431103, 71.25334214,
#        74.58660537, 69.60678195, 76.43559292, 81.14605479, 77.58528286,
#        80.03185134, 79.21060857, 79.19927609, 75.61787294, 69.42159775,
#        72.75053736, 71.04442296, 79.22698251, 74.23611217, 75.32351588,
#        77.22213445, 80.21130954, 75.08963807, 69.07158189, 72.64033154,
#        75.13333667, 78.14126013, 69.85576173, 81.54677433, 74.02236375,
#        72.53079918, 69.51767143, 68.77530786, 69.15526391, 74.41134904,
#        74.34090091, 69.89920369, 71.10977528, 72.67027902, 74.55975861,
#        69.37509799, 75.22848173, 77.64646481, 72.66576975, 73.24671727,
#        71.81469527, 79.49824247, 79.83147076, 81.5623317 , 77.73594474,
#        79.26253817, 72.41959339, 71.60761906, 67.7780465 , 79.99569192,
#        77.85189435, 68.79839392, 80.13830939, 69.88869229, 79.86833097,
#        72.93190053, 81.2604971 , 75.92320729, 79.90024807])

# %%
model.score(x_test,y_test)
# Out:
# 0.8623035905583257

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error
 
mae = mean_absolute_error(y_test,y_predicted)
mse = mean_squared_error(y_test,y_predicted) 

print("Mean absolute error : ",mae)
print("Mean squared error : ",mse)
# Out:
# Mean absolute error :  5.004472393543501
# Mean squared error :  38.439038003031314
